# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #
# #
# # 리스트, 튜플, 딕셔너리

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #
# #
# ### 앞서 배운 리스트와 튜플의 가장 큰 특징은 데이터를 구분할 때 순서, 즉 인덱스를 사용하여 구분하였음
# #### 다음과 같이 학생들의 학점을 저장한 리스트를 보자

# %%
score_list = ['A', 'B', 'A', 'C', 'C', 'A', 'A', 'B', 'C', 'A', 'B', 'C', 'B', 'A', 'A', 'A', 'B']
print(len(score_list))
print(score_list)
# Out:
# 17
# ['A', 'B', 'A', 'C', 'C', 'A', 'A', 'B', 'C', 'A', 'B', 'C', 'B', 'A', 'A', 'A', 'B']

# %% [markdown]
# #### 문제 : 8번째 학생의 성적을 출력해보세요

# %%
# Out:
# B

# %% [markdown]
# #### 문제 : 12번째 학생의 성적을 A로 바꿔주세요

# %%
# Out:
# ['A', 'B', 'A', 'C', 'C', 'A', 'A', 'B', 'C', 'A', 'B', 'A', 'B', 'A', 'A', 'A', 'B']

# %% [markdown]
# ####
# ### 학생들의 학점을 저장한 리스트를 사용할 때 불편함은 어떤 학생이 어떤 학점을 가지고 있는지 바로 알기 힘듦
# ### 이를 해결하기 위해 딕셔너리를 사용한 예를 보자

# %%
score_dict = {'차지환' : 'A',
             '김태인' : 'B',
             '전지훈' : 'A',
             '최수현' : 'C',
             '김결이' : 'C',
             '박하은' : 'A',
             '김덕용' : 'A',
             '김수현' : 'B',
             '최유정' : 'C', 
             '강아연' : 'A',
             '고은비' : 'B', 
             '김나경' : 'C',
             '김주희' : 'B',
             '신호선' : 'A',
             '박유신' : 'A',
             '유가은' : 'A',
             '이아연' : 'B',}
print(score_dict)
# Out:
# {'차지환': 'A', '김태인': 'B', '전지훈': 'A', '최수현': 'C', '김결이': 'C', '박하은': 'A', '김덕용': 'A', '김수현': 'B', '최유정': 'C', '강아연': 'A', '고은비': 'B', '김나경': 'C', '김주희': 'B', '신호선': 'A', '박유신': 'A', '유가은': 'A', '이아연': 'B'}

# %%
name = input("학생 이름을 입력하세요 : ")
score = score_dict[name]
print(score)
# Out:
# 학생 이름을 입력하세요 : 김덕용
# A

# %% [markdown]
# ##
# ### 즉, 대학생들의 학점을 검색하는 것처럼 순서로 구분하는 상황이 불편한 경우,
# ### 학생들의 이름, 학번과 같이 유니크하게 구분할 수 있는 것을 사용할 수 있게 해주는 것이 딕셔너리임

# %% [markdown]
# #
# #
# # 딕셔너리 Dictionary : { Key : Value }

# %% [markdown]
# #### Dictionary는 한국 단어로 "사전" 을 의미함
# #### 네이버 단어 사전 사이트 : https://dict.naver.com/
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 사전 사용 방법
# #### 사전을 사용할 때, 우리는 찾고 싶은 키워드(Key)를 머릿 속에 가지고 사전을 검색해봄
# #### 사전에서 키워드(Key)에 대응하는 글을 발견하여 읽음

# %% [markdown]
# ##
# ## 프로그래밍에서 딕셔너리
# #### 프로그래밍에서 딕셔너리는 이렇게, 유니크하게 구분할 수 있는 키(Key) 와
# #### 키(Key) 에 대응하는 값(Value) 을 한 쌍으로,
# #### { } 안에 여러 개의 키와 값의 쌍을 가지고 있는 데이터형임
# ####
# #### 백과사전과 프로그래밍 딕셔너리 비교
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ##
# ### 딕셔너리 선언
# #### - 중괄호 { } 로 선언하며,
# #### - { } 안에 Key 값과 Value 값을 콜론 ":" 으로 구분하여 한 쌍을 만들어줘야함
# #### - { Key : Value }

# %%
word_dict = { "사과" : "사과나무의 열매" }
print(word_dict)
# Out:
# {'사과': '사과나무의 열매'}

# %% [markdown]
# ####
# #### 딕셔너리는 여러 개의 key : value를 넣을 수 있고 쉼표로 구분하며 항상 쌍을 이뤄야함

# %%
word_dict = { "사과" : "사과나무의 열매", "배" : "배나무의 열매"}
print(word_dict)
# Out:
# {'사과': '사과나무의 열매', '배': '배나무의 열매'}

# %% [markdown]
# ####
# ### 딕셔너리 Key 값과 Value 값 보는 방법
# #### 딕셔너리 클래스 내부에는 Key 값과 Value 값을 보는 함수가 있음

# %% [markdown]
# #### 1. 딕셔너리 Key 값을 보려면
# #### 딕셔너리.keys() 함수 사용

# %%
word_dict.keys()
# Out:
# dict_keys(['사과', '배'])

# %% [markdown]
# #### 2. 딕셔너리 Value 값을 보려면
# #### 딕셔너리.values() 함수 사용

# %%
word_dict.values()
# Out:
# dict_values(['사과나무의 열매', '배나무의 열매'])

# %% [markdown]
# #### 3. 딕셔너리의 Key 와 Value 모두 보려면
# #### 딕셔너리.items() 함수 사용

# %%
word_dict.items()
# Out:
# dict_items([('사과', '사과나무의 열매'), ('배', '배나무의 열매')])

# %% [markdown]
# ####
# #### 문제 : 오리 : 꽥꽥, 강아지 : 멍멍 을 딕셔너리로 만들어 출력해보세요

# %%
# Out:
# {'오리': '꽥꽥', '강아지': '멍멍'}

# %% [markdown]
# #### 문제 : 위 딕셔너리의 key값과 value 값을 각각 출력해보세요

# %%
# Out:
# key 값 :  dict_keys(['오리', '강아지'])
# value 값 :  dict_values(['꽥꽥', '멍멍'])

# %% [markdown]
# ####
# ### 딕셔너리의 데이터형

# %%
print(type(word_dict))
# Out:
# <class 'dict'>

# %% [markdown]
# ##
# ### 딕셔너리의 Key 와 Value 데이터형
# #### - Key 와 Value 값은 int, float, str 등 다양한 데이터형을 사용할 수 있음
# #### - 숫자(int, float)과 문자(str) 을 자유롭게 사용 가능함

# %% [markdown]
# #### 딕셔너리 Key, Value 데이터형 조합
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1. Key 와 Value 모두 숫자인 경우
# 예 : 1등은 100만원, 2등은 50만원 3등은 30만원의 상금을 주려고 하는 경우

# %%
A = {1:100, 2:50, 3:30}
print(A)
# Out:
# {1: 100, 2: 50, 3: 30}

# %% [markdown]
# ####
# #### 2. Key는 숫자, Value는 문자인 경우
# 예 : 1등은 고영민, 2등은 김광배, 3등은 최문열로 등록할 경우

# %%
A = {1 : '고영민', 2 : '김광배', 3 : '최문열'}
print(A)
# Out:
# {1: '고영민', 2: '김광배', 3: '최문열'}

# %% [markdown]
# ####
# #### 3. Key는 문자, Value는 숫자인 경우
# 예 : 학생이름과 성적

# %%
A = {'고영민' : 50, '김광배' : 100, '최문열' : 80}
print(A)
# Out:
# {'고영민': 50, '김광배': 100, '최문열': 80}

# %% [markdown]
# #### 4. Key와 Value 모두 문자인 경우

# %%
word_dict = { "사과" : "사과나무의 열매", "배" : "배나무의 열매"}
print(word_dict)
# Out:
# {'사과': '사과나무의 열매', '배': '배나무의 열매'}

# %% [markdown]
# ####
# #### 문제 : 다음 아래와 같은 표를 보고 딕셔너리로 만들어 출력해보세요
# ![image-3.png](attachment:image-3.png)

# %%
# Out:
# {'a': 100, 'b': 80, 'c': 50, 'd': 90}

# %% [markdown]
# ##
# ### 딕셔너리 내에 데이터 접근 방법
# #### - 딕셔너리는 리스트, 튜플과 다르게 순서 기반인 인덱스가 아니라 키(Key) 값을 사용하여 데이터에 접근함
# #### - 딕셔너리[Key값] 으로 Key 값에 대응하는 Value 값에 접근할 수 있음

# %%
A = {'a' : 100, 'b' : 80, 'c':50, 'd':90}
print(A)
# Out:
# {'a': 100, 'b': 80, 'c': 50, 'd': 90}

# %% [markdown]
# #### 예를 들어, 위의 딕셔너리에서 d 의 성적이 궁금하다면?

# %%
print(A['d'])
# Out:
# 90

# %% [markdown]
# #### 즉 딕셔너리[ ] 괄호 안에 Key 값을 넣어 접근해볼 수 있음. a,b,c,d 모두 값을 출력하면 다음과 같음

# %%
print(A['a'])
print(A['b'])
print(A['c'])
print(A['d'])
# Out:
# 100
# 80
# 50
# 90

# %% [markdown]
# ####
# #### 문제 : 다음과 같은 일본언어문화학과 학생들의 학점 딕셔너리가 있다고 해보자

# %%
score_dict = {'차지환' : 'A',
             '김태인' : 'B',
             '전지훈' : 'A',
             '최수현' : 'C',
             '김결이' : 'C',
             '박하은' : 'A',
             '김덕용' : 'A',
             '김수현' : 'B',
             '최유정' : 'C', 
             '강아연' : 'A',
             '고은비' : 'B', 
             '김나경' : 'C',
             '김주희' : 'B',
             '신호선' : 'A',
             '박유신' : 'A',
             '유가은' : 'A',
             '이아연' : 'B',
             '고영민' : 'F'}
print(score_dict)
# Out:
# {'차지환': 'A', '김태인': 'B', '전지훈': 'A', '최수현': 'C', '김결이': 'C', '박하은': 'A', '김덕용': 'A', '김수현': 'B', '최유정': 'C', '강아연': 'A', '고은비': 'B', '김나경': 'C', '김주희': 'B', '신호선': 'A', '박유신': 'A', '유가은': 'A', '이아연': 'B', '고영민': 'F'}

# %% [markdown]
# #### 문제 : 고영민의 학점을 출력해보세요

# %%
# Out:
# F

# %% [markdown]
# ### 또한 딕셔너리에서는 Value 값을 바꿀 수 있음
# #### 딕셔너리[key값] = 새로운 값

# %% [markdown]
# #### 고영민의 학점을 A 로 변경한다면 다음과 같음

# %%
score_dict['고영민'] = 'A'
print(score_dict)
# Out:
# {'차지환': 'A', '김태인': 'B', '전지훈': 'A', '최수현': 'C', '김결이': 'C', '박하은': 'A', '김덕용': 'A', '김수현': 'B', '최유정': 'C', '강아연': 'A', '고은비': 'B', '김나경': 'C', '김주희': 'B', '신호선': 'A', '박유신': 'A', '유가은': 'A', '이아연': 'B', '고영민': 'A'}

# %% [markdown]
# ####
# #### 문제 : 학점이 C인 학생들의 성적을 모두 A로 바꿔서 출력해주세요

# %% [markdown]
# ####
# ### 딕셔너리와 반복문을 함께 사용하는 방법
# #### 반복문 요소에 딕셔너리를 넣게될 경우 출력은 Key 값들만 출력하게 됨

# %%
for key in score_dict:
    print(key)
# Out:
# 차지환
# 김태인
# 전지훈
# 최수현
# 김결이
# 박하은
# 김덕용
# 김수현
# 최유정
# 강아연
# 고은비
# 김나경
# 김주희
# 신호선
# 박유신
# 유가은
# 이아연
# 고영민

# %% [markdown]
# #### Value 값들을 보려면 이 key 값들을 다음과 같이 사용할 수 있음

# %%
for key in score_dict:
    print(score_dict[key])
# Out:
# A
# B
# A
# C
# C
# A
# A
# B
# C
# A
# B
# C
# B
# A
# A
# A
# B
# A

# %% [markdown]
# #### 그럼, 학점인 C 인 친구들을 A 로 바꿔주는 방법을 반복문을 사용한다면 다음과 같이 할 수 있음

# %%
for key in score_dict:
    if score_dict[key] == 'C':
        score_dict[key] = 'A'
    
    print(score_dict[key])
# Out:
# A
# B
# A
# A
# A
# A
# A
# B
# A
# A
# B
# A
# B
# A
# A
# A
# B
# A

# %% [markdown]
# #### 이제 학생 이름과 학점을 모두 출력해보자

# %%
print(score_dict)
# Out:
# {'차지환': 'A', '김태인': 'B', '전지훈': 'A', '최수현': 'A', '김결이': 'A', '박하은': 'A', '김덕용': 'A', '김수현': 'B', '최유정': 'A', '강아연': 'A', '고은비': 'B', '김나경': 'A', '김주희': 'B', '신호선': 'A', '박유신': 'A', '유가은': 'A', '이아연': 'B', '고영민': 'A'}

# %% [markdown]
# ##
# #### * 참고사항 : 딕셔너리는 키 값으로 구분하므로 동일한 키 값을 가질 수 없음,
# #### 하지만 파이썬에서는 동일한 키 값이 있는 딕셔너리의 경우에 마지막 키 값이 출력됨
# #### 가급적이면 딕셔너리에서는 키 값이 구분되어야 함

# %%
word = {'사과' : '맛있음', '사과' : '달콤함'}
print(word)
# Out:
# {'사과': '달콤함'}
